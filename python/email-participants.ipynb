# %%
import pandas as pd
df = pd.read_csv("../2024/leaderboard/data/submissions2024.csv")

# %%
df['diff'] = df['round_9_rank'] - df['round_8_rank']

# %%
display(df.sort_values('diff').head(10))
# Out:
#    leaderboardAlias                                         prediction  \
# 39         Jitesh J  hutchinson,christie,suarez,hurd,pence,ramaswam...
# 34              SSR  hurd,suarez,ramaswamy,elder,hutchinson,desanti...
# 21         Karsen B  burgum,hutchinson,christie,elder,haley,suarez,...
# 20       Chelsey  M  burgum,elder,christie,scott,hurd,hutchinson,pe...
# 40          Chris C  burgum,hutchinson,hurd,suarez,pence,christie,e...
# 43    Eamon Omaille  elder,hutchinson,hurd,suarez,haley,christie,sc...
# 17    Jeremy Torres  hurd,hutchinson,burgum,elder,suarez,ramaswamy,...
# 63      Nathaniel S  suarez,burgum,elder,hutchinson,hurd,haley,rama...
# 56     Matt Nowling  suarez,burgum,hutchinson,haley,hurd,elder,scot...
# 2             ian s  burgum,elder,suarez,hutchinson,hurd,haley,rama...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 39              2              4              9             11             14
# ...

# %%
display(df.sort_values('diff').tail(10))
# Out:
#    leaderboardAlias                                         prediction  \
# 12         Jordan S  hurd,christie,haley,scott,suarez,hutchinson,pe...
# 33           Kerr S  scott,suarez,ramaswamy,haley,burgum,hurd,hutch...
# 23              S G  burgum,hurd,scott,ramaswamy,elder,trump,suarez...
# 75          Ellie L  burgum,elder,hurd,suarez,desantis,hutchinson,h...
# 49          Paolo M  hurd,burgum,ramaswamy,suarez,haley,elder,hutch...
# 10              MMS  suarez,hurd,elder,burgum,haley,hutchinson,desa...
# 11     Devin Meenan  suarez,ramaswamy,elder,burgum,desantis,hutchin...
# 45    Zack Schuster  hurd,ramaswamy,haley,elder,scott,hutchinson,su...
# 16         Karlos A  hurd,burgum,suarez,elder,haley,pence,ramaswamy...
# 3               K G  elder,hurd,suarez,ramaswamy,scott,haley,desant...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 12              4              4             10             14             16
# ...

# %%
df.sort_values('round_9_score').head(15)
# Out:
#        leaderboardAlias                                         prediction  \
# 76              Karla A  suarez,scott,burgum,hurd,elder,hutchinson,penc...
# 1               Katie R  elder,suarez,hurd,burgum,hutchinson,scott,penc...
# 41              djbayko  suarez,elder,hurd,burgum,hutchinson,pence,chri...
# 7              Keerit K  hurd,suarez,burgum,elder,scott,hutchinson,chri...
# 71                   SG  suarez,elder,hurd,burgum,christie,hutchinson,s...
# 78  Wisdom of the crowd  hurd,elder,suarez,burgum,hutchinson,scott,chri...
# 50    tehspeleengpolise  suarez,elder,hurd,hutchinson,pence,burgum,chri...
# 58           Bobby King  suarez,hurd,elder,burgum,hutchinson,ramaswamy,...
# 29             Lucian W  hurd,scott,suarez,burgum,elder,hutchinson,penc...
# 55               Adam S  suarez,hurd,burgum,elder,hutchinson,haley,penc...
# 72                   KG  hurd,elder,suarez,hutchinson,burgum,scott,chri...
# ...
