# %%
import pandas as pd
df = pd.read_csv("../2024/leaderboard/data/submissions2024.csv")

# %%
df['diff'] = df['round_7_rank'] - df['round_6_rank']

# %%
display(df.sort_values('diff').head(10))
# Out:
#    leaderboardAlias                                         prediction  \
# 54        Refused68  elder,suarez,christie,hurd,hutchinson,burgum,p...
# 65          Logan G  elder,hurd,burgum,christie,hutchinson,ramaswam...
# 14             Jake  burgum,elder,hurd,suarez,christie,hutchinson,r...
# 39         Jitesh J  hutchinson,christie,suarez,hurd,pence,ramaswam...
# 36           Mike D  hutchinson,christie,hurd,elder,suarez,burgum,s...
# 38        matthew d  hurd,suarez,elder,hutchinson,christie,scott,bu...
# 71               SG  suarez,elder,hurd,burgum,christie,hutchinson,s...
# 20       Chelsey  M  burgum,elder,christie,scott,hurd,hutchinson,pe...
# 4           Angie P  hurd,burgum,elder,hutchinson,christie,pence,su...
# 26     Khari  Brown  elder,suarez,burgum,scott,hurd,hutchinson,chri...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 54              1              3              3              6             10
# 65              6              7              7             13             17
# 14              3              5              6             11             16
# 39              2              4              9             11             14
# 36              4              6              8             12             15
# 38              1              1              1              8             10
# 71              0              1              1              7             10
# 20              8             12             13             17             19
# 4               6              6              7             10             14
# 26              1              4              4             10             11
#
#     round_6_score  round_7_score  kendallDistance  rank  round_1_rank  \
# 54             12             12               12  17.0          20.0
# 65             17             17               17  45.0          67.0
# 14             16             16               16  40.0          46.0
# 39             17             18               18  48.0          34.0
# 36             17             18               18  48.0          54.0
# 38             12             13               13  22.0          20.0
# 71             10             10               10   5.0           1.0
# 20             19             19               19  58.0          75.0
# 4              14             15               15  35.0          67.0
# 26             11             12               12  17.0          20.0
#
#     round_2_rank  round_3_rank  round_4_rank  round_5_rank  round_6_rank  \
# 54          30.0          25.0          15.0          20.0          32.0
# 65          63.0          55.0          60.0          63.0          58.0
# 14          48.0          44.0          50.0          56.0          51.0
# 39          41.0          63.0          50.0          44.0          58.0
# 36          58.0          58.0          56.0          50.0          58.0
# 38           5.0           4.0          28.0          20.0          32.0
# 71           5.0           4.0          21.0          20.0          12.0
# 20          76.0          74.0          72.0          72.0          64.0
# 4           58.0          55.0          40.0          44.0          41.0
# 26          41.0          30.0          40.0          33.0          23.0
#
#     round_7_rank  diff
# 54          17.0 -15.0
# 65          45.0 -13.0
# 14          40.0 -11.0
# 39          48.0 -10.0
# 36          48.0 -10.0
# 38          22.0 -10.0
# 71           5.0  -7.0
# 20          58.0  -6.0
# 4           35.0  -6.0
# 26          17.0  -6.0

# %%
display(df.sort_values('diff').tail(10))
# Out:
#      leaderboardAlias                                         prediction  \
# 52            Boopsie  suarez,hurd,elder,hutchinson,desantis,burgum,p...
# 30          Michael A  elder,suarez,hurd,burgum,hutchinson,ramaswamy,...
# 3                 K G  elder,hurd,suarez,ramaswamy,scott,haley,desant...
# 10                MMS  suarez,hurd,elder,burgum,haley,hutchinson,desa...
# 25      Eric Spengler  elder,suarez,burgum,hutchinson,hurd,scott,rama...
# 68        Josh Bellis  hurd,elder,suarez,hutchinson,haley,burgum,desa...
# 34                SSR  hurd,suarez,ramaswamy,elder,hutchinson,desanti...
# 37         Harrison K  hurd,hutchinson,suarez,elder,pence,burgum,desa...
# 19       David Warren  suarez,elder,hutchinson,hurd,haley,burgum,scot...
# 64  Oliver Gladfelter  suarez,hutchinson,hurd,elder,burgum,haley,penc...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 52              0              0              0              3              9
# 30              1              2              2              8             11
# 3               2              3              3              9             10
# 10              0              0              0              4             10
# 25              1              4              4              8             10
# 68              2              2              2              9             14
# 34              1              1              2              8             13
# 37              2              2              3              4              7
# 19              0              2              2              6              9
# 64              0              1              2              5              8
#
#     round_6_score  round_7_score  kendallDistance  rank  round_1_rank  \
# 52             11             14               14  31.0           1.0
# 30             11             14               14  31.0          20.0
# 3              13             17               17  45.0          34.0
# 10             10             13               13  22.0           1.0
# 25             10             13               13  22.0          20.0
# 68             16             20               20  62.0          34.0
# 34             16             20               20  62.0          20.0
# 37              8             12               12  17.0          34.0
# 19             11             15               15  35.0           1.0
# 64              9             13               13  22.0           1.0
#
#     round_2_rank  round_3_rank  round_4_rank  round_5_rank  round_6_rank  \
# 52           1.0           1.0           2.0          13.0          23.0
# 30          15.0          10.0          28.0          33.0          23.0
# 3           30.0          25.0          36.0          20.0          36.0
# 10           1.0           1.0           4.0          20.0          12.0
# 25          41.0          30.0          28.0          20.0          12.0
# 68          15.0          10.0          36.0          44.0          51.0
# 34           5.0          10.0          28.0          40.0          51.0
# 37          15.0          25.0           4.0           2.0           6.0
# 19          15.0          10.0          15.0          13.0          23.0
# 64           5.0          10.0           8.0           7.0           9.0
#
#     round_7_rank  diff
# 52          31.0   8.0
# 30          31.0   8.0
# 3           45.0   9.0
# 10          22.0  10.0
# 25          22.0  10.0
# 68          62.0  11.0
# 34          62.0  11.0
# 37          17.0  11.0
# 19          35.0  12.0
# 64          22.0  13.0
