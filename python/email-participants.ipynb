# %%
import pandas as pd
df = pd.read_csv("../2024/leaderboard/data/submissions2024.csv")

# %%
df['diff'] = df['round_4_rank'] - df['round_3_rank']

# %%
display(df.sort_values('diff').head(10))
# Out:
#       leaderboardAlias                                         prediction  \
# 8   Robert Middlekauff  elder,pence,suarez,hutchinson,hurd,burgum,chri...
# 37          Harrison K  hurd,hutchinson,suarez,elder,pence,burgum,desa...
# 48              Paul R  elder,scott,hurd,burgum,pence,hutchinson,suare...
# 16            Karlos A  hurd,burgum,suarez,elder,haley,pence,ramaswamy...
# 70     V for Veepdetta  burgum,suarez,hutchinson,hurd,pence,elder,hale...
# 35           Rob Moore  burgum,hurd,elder,suarez,hutchinson,pence,hale...
# 4              Angie P  hurd,burgum,elder,hutchinson,christie,pence,su...
# 22             Slaboch  hurd,hutchinson,elder,suarez,burgum,pence,hale...
# 39            Jitesh J  hutchinson,christie,suarez,hurd,pence,ramaswam...
# 40             Chris C  burgum,hutchinson,hurd,suarez,pence,christie,e...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  \
# 8               2              5              5              5
# 37              2              2              3              4
# 48              6              8              8             10
# 16              2              2              3              5
# 70              1              3              6              8
# 35              3              4              5              7
# 4               6              6              7             10
# 22              3              3              4              6
# 39              2              4              9             11
# 40              3              5              9             11
#
#     kendallDistance  rank  round_1_rank  round_2_rank  round_3_rank  \
# 8                 5   8.0          34.0          48.0          37.0
# 37                4   4.0          34.0          15.0          25.0
# 48               10  40.0          67.0          68.0          58.0
# 16                5   8.0          34.0          15.0          25.0
# 70                8  28.0          20.0          30.0          44.0
# 35                7  21.0          46.0          41.0          37.0
# 4                10  40.0          67.0          58.0          55.0
# 22                6  15.0          46.0          30.0          30.0
# 39               11  50.0          34.0          41.0          63.0
# 40               11  50.0          46.0          48.0          63.0
#
#     round_4_rank  diff
# 8            8.0 -29.0
# 37           4.0 -21.0
# 48          40.0 -18.0
# 16           8.0 -17.0
# 70          28.0 -16.0
# 35          21.0 -16.0
# 4           40.0 -15.0
# 22          15.0 -15.0
# 39          50.0 -13.0
# 40          50.0 -13.0

# %%
display(df.sort_values('diff').tail(10))
# Out:
#        leaderboardAlias                                         prediction  \
# 17        Jeremy Torres  hurd,hutchinson,burgum,elder,suarez,ramaswamy,...
# 49              Paolo M  hurd,burgum,ramaswamy,suarez,haley,elder,hutch...
# 62            Rebecca O  elder,hurd,ramaswamy,christie,hutchinson,suare...
# 71                   SG  suarez,elder,hurd,burgum,christie,hutchinson,s...
# 74              Annie J  hurd,burgum,hutchinson,suarez,scott,elder,hale...
# 30            Michael A  elder,suarez,hurd,burgum,hutchinson,ramaswamy,...
# 34                  SSR  hurd,suarez,ramaswamy,elder,hutchinson,desanti...
# 78  Wisdom of the crowd  hurd,elder,suarez,burgum,hutchinson,scott,chri...
# 38            matthew d  hurd,suarez,elder,hutchinson,christie,scott,bu...
# 68          Josh Bellis  hurd,elder,suarez,hutchinson,haley,burgum,desa...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  \
# 17              4              4              6             12
# 49              3              3              6             12
# 62              5              6              6             12
# 71              0              1              1              7
# 74              3              3              6             14
# 30              1              2              2              8
# 34              1              1              2              8
# 78              2              2              2              8
# 38              1              1              1              8
# 68              2              2              2              9
#
#     kendallDistance  rank  round_1_rank  round_2_rank  round_3_rank  \
# 17               12  56.0          54.0          41.0          44.0
# 49               12  56.0          46.0          30.0          44.0
# 62               12  56.0          60.0          58.0          44.0
# 71                7  21.0           1.0           5.0           4.0
# 74               14  61.0          46.0          30.0          44.0
# 30                8  28.0          20.0          15.0          10.0
# 34                8  28.0          20.0           5.0          10.0
# 78                8  28.0          34.0          15.0          10.0
# 38                8  28.0          20.0           5.0           4.0
# 68                9  36.0          34.0          15.0          10.0
#
#     round_4_rank  diff
# 17          56.0  12.0
# 49          56.0  12.0
# 62          56.0  12.0
# 71          21.0  17.0
# 74          61.0  17.0
# 30          28.0  18.0
# 34          28.0  18.0
# 78          28.0  18.0
# 38          28.0  24.0
# 68          36.0  26.0

# %%
df.sort_values('rank')[:15]
# Out:
#       leaderboardAlias                                         prediction  \
# 50   tehspeleengpolise  suarez,elder,hurd,hutchinson,pence,burgum,chri...
# 41             djbayko  suarez,elder,hurd,burgum,hutchinson,pence,chri...
# 52             Boopsie  suarez,hurd,elder,hutchinson,desantis,burgum,p...
# 37          Harrison K  hurd,hutchinson,suarez,elder,pence,burgum,desa...
# 6               Jake G  hurd,suarez,elder,hutchinson,haley,christie,pe...
# 10                 MMS  suarez,hurd,elder,burgum,haley,hutchinson,desa...
# 55              Adam S  suarez,hurd,burgum,elder,hutchinson,haley,penc...
# 58          Bobby King  suarez,hurd,elder,burgum,hutchinson,ramaswamy,...
# 8   Robert Middlekauff  elder,pence,suarez,hutchinson,hurd,burgum,chri...
# 1              Katie R  elder,suarez,hurd,burgum,hutchinson,scott,penc...
# 15                 mmm  suarez,elder,burgum,hurd,hutchinson,christie,p...
# 16            Karlos A  hurd,burgum,suarez,elder,haley,pence,ramaswamy...
# 64   Oliver Gladfelter  suarez,hutchinson,hurd,elder,burgum,haley,penc...
# 18      John Hawthorne  suarez,hutchinson,hurd,elder,christie,haley,pe...
# 9          Nick Devlin  suarez,elder,hutchinson,hurd,christie,scott,bu...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  \
# 50              0              1              1              2
# 41              0              1              1              3
# 52              0              0              0              3
# 37              2              2              3              4
# 6               1              1              1              4
# 10              0              0              0              4
# 55              0              0              1              4
# 58              0              0              0              5
# 8               2              5              5              5
# 1               1              2              2              5
# 15              0              2              2              5
# 16              2              2              3              5
# 64              0              1              2              5
# 18              0              1              2              5
# 9               0              2              2              6
#
#     kendallDistance  rank  round_1_rank  round_2_rank  round_3_rank  \
# 50                2   1.0           1.0           5.0           4.0
# 41                3   2.0           1.0           5.0           4.0
# 52                3   2.0           1.0           1.0           1.0
# 37                4   4.0          34.0          15.0          25.0
# 6                 4   4.0          20.0           5.0           4.0
# 10                4   4.0           1.0           1.0           1.0
# 55                4   4.0           1.0           1.0           4.0
# 58                5   8.0           1.0           1.0           1.0
# 8                 5   8.0          34.0          48.0          37.0
# 1                 5   8.0          20.0          15.0          10.0
# 15                5   8.0           1.0          15.0          10.0
# 16                5   8.0          34.0          15.0          25.0
# 64                5   8.0           1.0           5.0          10.0
# 18                5   8.0           1.0           5.0          10.0
# 9                 6  15.0           1.0          15.0          10.0
#
#     round_4_rank  diff
# 50           1.0  -3.0
# 41           2.0  -2.0
# 52           2.0   1.0
# 37           4.0 -21.0
# 6            4.0   0.0
# 10           4.0   3.0
# 55           4.0   0.0
# 58           8.0   7.0
# 8            8.0 -29.0
# 1            8.0  -2.0
# 15           8.0  -2.0
# 16           8.0 -17.0
# 64           8.0  -2.0
# 18           8.0  -2.0
# 9           15.0   5.0
