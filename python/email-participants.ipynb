# %%
import pandas as pd
df = pd.read_csv("../2024/leaderboard/data/submissions2024.csv")

# %%
df['diff'] = df['round_6_rank'] - df['round_5_rank']

# %%
display(df.sort_values('diff').head(10))
# Out:
#        leaderboardAlias                                         prediction  \
# 35            Rob Moore  burgum,hurd,elder,suarez,hutchinson,pence,hale...
# 26         Khari  Brown  elder,suarez,burgum,scott,hurd,hutchinson,chri...
# 30            Michael A  elder,suarez,hurd,burgum,hutchinson,ramaswamy,...
# 25        Eric Spengler  elder,suarez,burgum,hutchinson,hurd,scott,rama...
# 15                  mmm  suarez,elder,burgum,hurd,hutchinson,christie,p...
# 10                  MMS  suarez,hurd,elder,burgum,haley,hutchinson,desa...
# 20           Chelsey  M  burgum,elder,christie,scott,hurd,hutchinson,pe...
# 78  Wisdom of the crowd  hurd,elder,suarez,burgum,hutchinson,scott,chri...
# 48               Paul R  elder,scott,hurd,burgum,pence,hutchinson,suare...
# 77              David H  suarez,burgum,hurd,elder,hutchinson,haley,scot...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 35              3              4              5              7             11
# 26              1              4              4             10             11
# 30              1              2              2              8             11
# 25              1              4              4              8             10
# 15              0              2              2              5             10
# 10              0              0              0              4             10
# 20              8             12             13             17             19
# 78              2              2              2              8             10
# 48              6              8              8             10             10
# 77              0              1              2              7             10
#
#     round_6_score  kendallDistance  rank  round_1_rank  round_2_rank  \
# 35             11               11  23.0          46.0          41.0
# 26             11               11  23.0          20.0          41.0
# 30             11               11  23.0          20.0          15.0
# 25             10               10  12.0          20.0          41.0
# 15             10               10  12.0           1.0          15.0
# 10             10               10  12.0           1.0           1.0
# 20             19               19  64.0          75.0          76.0
# 78             10               10  12.0          34.0          15.0
# 48             10               10  12.0          67.0          68.0
# 77             10               10  12.0           1.0           5.0
#
#     round_3_rank  round_4_rank  round_5_rank  round_6_rank  diff
# 35          37.0          21.0          33.0          23.0 -10.0
# 26          30.0          40.0          33.0          23.0 -10.0
# 30          10.0          28.0          33.0          23.0 -10.0
# 25          30.0          28.0          20.0          12.0  -8.0
# 15          10.0           8.0          20.0          12.0  -8.0
# 10           1.0           4.0          20.0          12.0  -8.0
# 20          74.0          72.0          72.0          64.0  -8.0
# 78          10.0          28.0          20.0          12.0  -8.0
# 48          58.0          40.0          20.0          12.0  -8.0
# 77          10.0          21.0          20.0          12.0  -8.0

# %%
display(df.sort_values('diff').tail(10))
# Out:
#    leaderboardAlias                                         prediction  \
# 42      Ryan Branch  elder,suarez,hurd,hutchinson,ramaswamy,burgum,...
# 34              SSR  hurd,suarez,ramaswamy,elder,hutchinson,desanti...
# 43    Eamon Omaille  elder,hutchinson,hurd,suarez,haley,christie,sc...
# 38        matthew d  hurd,suarez,elder,hutchinson,christie,scott,bu...
# 54        Refused68  elder,suarez,christie,hurd,hutchinson,burgum,p...
# 45    Zack Schuster  hurd,ramaswamy,haley,elder,scott,hutchinson,su...
# 39         Jitesh J  hutchinson,christie,suarez,hurd,pence,ramaswam...
# 18   John Hawthorne  suarez,hutchinson,hurd,elder,christie,haley,pe...
# 6            Jake G  hurd,suarez,elder,hutchinson,haley,christie,pe...
# 3               K G  elder,hurd,suarez,ramaswamy,scott,haley,desant...
#
#     round_1_score  round_2_score  round_3_score  round_4_score  round_5_score  \
# 42              1              2              2              6              9
# 34              1              1              2              8             13
# 43              3              5              5             10             13
# 38              1              1              1              8             10
# 54              1              3              3              6             10
# 45              6              6              8             14             16
# 39              2              4              9             11             14
# 18              0              1              2              5             10
# 6               1              1              1              4              8
# 3               2              3              3              9             10
#
#     round_6_score  kendallDistance  rank  round_1_rank  round_2_rank  \
# 42             11               11  23.0          20.0          15.0
# 34             16               16  51.0          20.0           5.0
# 43             16               16  51.0          46.0          48.0
# 38             12               12  32.0          20.0           5.0
# 54             12               12  32.0          20.0          30.0
# 45             20               20  69.0          67.0          58.0
# 39             17               17  58.0          34.0          41.0
# 18             13               13  36.0           1.0           5.0
# 6              11               11  23.0          20.0           5.0
# 3              13               13  36.0          34.0          30.0
#
#     round_3_rank  round_4_rank  round_5_rank  round_6_rank  diff
# 42          10.0          15.0          13.0          23.0  10.0
# 34          10.0          28.0          40.0          51.0  11.0
# 43          37.0          40.0          40.0          51.0  11.0
# 38           4.0          28.0          20.0          32.0  12.0
# 54          25.0          15.0          20.0          32.0  12.0
# 45          58.0          61.0          56.0          69.0  13.0
# 39          63.0          50.0          44.0          58.0  14.0
# 18          10.0           8.0          20.0          36.0  16.0
# 6            4.0           4.0           7.0          23.0  16.0
# 3           25.0          36.0          20.0          36.0  16.0
